# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
image=Image.open("AVI PASSPORT SIZE 1.jpg")
image2= Image.open('1917p5_1.jpg')

# %%
image.show()

# %%
plt.imshow(image)

# %%
plt.imshow(image2)

# %%
print(image.size)
print(image.format)
print(image.mode)
# Out:
# (413, 531)
# JPEG
# RGB

# %%
image.save("new.jpg")

# %%
left=50
top=120
right=250
bottom=230
crop_image=image.crop((left,top,right,bottom))
plt.imshow(crop_image)

# %%
copied_image=image.copy()
plt.imshow(copied_image)

# %%
import PIL
transpose_image1=image.transpose(Image.FLIP_RIGHT)
transpose_image2=image.transpose(Image.FLIP_BOTTOM)
transpose_image3=image.transpose(Image.ROTATE_90)
transpose_image4=image.transpose(Image.ROTATE_180)
transpose_image5=image.transpose(Image.ROTATE_270)
transpose_image6=image.transpose(Image.TRANSPOSE)
plt.figure(figsize=(10,10))
plt.subplot(3,2,1)
plt.imshow(transpose_image1)
plt.title("FLIP_LEFT_RIGHT")
plt.subplot(3,2,2)
plt.imshow(transpose_image2)
plt.title("FLIP_LEFT_BOTTOM")
plt.subplot(3,2,3)
plt.imshow(transpose_image3)
plt.title("ROTATE_90")
plt.subplot(3,2,4)
plt.imshow(transpose_image4)
plt.title("ROTATE_180")
plt.subplot(3,2,5)
plt.imshow(transpose_image5)
plt.title("ROTATE_270")
plt.subplot(3,2,6)
plt.imshow(transpose_image6)
plt.title("ROTATE_270")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [21], line 2
#       1 import PIL
# ----> 2 transpose_image1=image.transpose(Image.FLIP_RIGHT)
#       3 transpose_image2=image.transpose(Image.FLIP_BOTTOM)
#       4 transpose_image3=image.transpose(Image.ROTATE_90)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:76, in __getattr__(name)
#      74         deprecate(name, 10, f"{enum.__name__}.{name}")
#      75         return enum[name]
# ---> 76 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'PIL.Image' has no attribute 'FLIP_RIGHT'

# %%
import PIL

print(PIL.PILLOW_VERSION)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [17], line 3
#       1 import PIL
# ----> 3 print(PIL.PILLOW_VERSION)
#
# AttributeError: module 'PIL' has no attribute 'PILLOW_VERSION'

# %%
angle=30
rotated_image=image.rotate(angle)
plt.imshow(rotated_image)

# %%
from PIL import ImageFont
from PIL import ImageDraw
watermarked_image=image.copy()
draw=ImageDraw.Draw(watermarked_image)
font = ImageFont.truetype("arial.ttf",100)

draw.text((10,10),"sample Text",(5,5,5),font=font)
plt.imshow(watermarked_image)

# %%
bw_image=image.convert('L')
plt.imshow(bw_image,cmap='gray')

# %%
numpy_array=np.array(image)
print(numpy_array.shape)
# Out:
# (531, 413, 3)

# %%
numpy_image=Image.fromarray(numpy_array)
plt.imshow(numpy_array)
